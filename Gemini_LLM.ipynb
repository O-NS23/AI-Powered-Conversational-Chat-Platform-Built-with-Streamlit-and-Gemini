# %% [markdown]
# <a href="https://colab.research.google.com/github/O-NS23/AI-Powered-Conversational-Chat-Platform-Built-with-Streamlit-and-Gemini/blob/main/Gemini_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata

# 1. Setup
my_key = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=my_key)

# 2. THE SEARCH PARTY: Find which models you can actually use
print("Searching for available brains...")
available_models = [m.name for m in genai.list_models() if 'generateContent' in m.supported_generation_methods]

if not available_models:
    print("❌ No models found. Check your API key!")
else:
    # Pick the first smart model found (usually gemini-1.5-flash or gemini-pro)
    chosen_model = available_models[0]
    print(f"✅ Found it! Using: {chosen_model}")

    # 3. Connect and Chat
    model = genai.GenerativeModel(chosen_model)
    user_question = "How should a Data Science Fresher Resume look?"

    try:
        response = model.generate_content(user_question)
        print("-" * 30)
        print(f"AI: {response.text}")
    except Exception as e:
        print(f"Still a snag: {e}")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Searching for available brains...
# ✅ Found it! Using: models/gemini-2.5-flash
# ------------------------------
# AI: A Data Science Fresher's resume needs to **compensate for the lack of professional experience by highlighting potential, demonstrated skills, and relevant projects.** It's about showcasing your foundational knowledge, practical application through projects, enthusiasm, and readiness to learn and contribute.
#
# Here's a breakdown of how a strong Data Science Fresher resume should look, section by section:
#
# ---
#
# ### **1. Contact Information (Top of the Page)**
#
# *   **Full Name:** Prominently displayed.
# *   **Phone Number:** Professional cell phone.
# *   **Email Address:** Professional-looking (e.g., `firstname.lastname@email.com`).
# *   **LinkedIn Profile URL:** Make sure it's up-to-date and professional.
# *   **GitHub Profile URL:** **Crucial for freshers.** This is your portfolio. Ensure it contains well-documented, relevant data science projects.
# *   **(Optional) Personal Portfolio/Blog URL:** If you have a website showcasing projects, articles, or data visualizations.
# *   **(Optional) Location:** City, State (no need for full address).
#
# ---
#
# ### **2. Summary / Objective (2-4 Lines)**
#
# This is your elevator pitch. Since you lack experience, an **Objective** might be more appropriate, stating your career goal and highlighting key strengths.
#
# *   **For an Objective:**
#     "Highly motivated and analytical Computer Science graduate with a strong foundation in machine learning, statistical modeling, and data visualization, seeking an entry-level Data Scientist role to apply technical skills and contribute to data-driven decision-making."
# *   **For a Summary (if you have relevant internships):**
#     "Recent [Your Degree] graduate passionate about leveraging data to solve complex problems. Proficient in Python (Pandas, Scikit-learn, Matplotlib), SQL, and statistical analysis, with hands-on experience in predictive modeling and data visualization from academic projects and a [mention brief internship role/focus]."
#
# **Key elements to include:**
# *   Your degree/background.
# *   2-3 core data science skills (e.g., ML, stats, visualization, specific tools).
# *   Your career goal (e.g., "seeking a Data Scientist role").
# *   Enthusiasm for data-driven problem-solving.
#
# ---
#
# ### **3. Skills (Categorized & Prominent)**
#
# This section is vital for ATS (Applicant Tracking Systems) and quick recruiter scans. List skills you're genuinely proficient in.
#
# *   **Programming Languages:** Python (Pandas, NumPy, SciPy, Scikit-learn, Matplotlib, Seaborn, Plotly, Streamlit, Flask/Django), R, SQL, Java (if relevant), Scala (if relevant).
# *   **Machine Learning:** Supervised/Unsupervised Learning, Regression, Classification, Clustering, Deep Learning (CNNs, RNNs), NLP, Time Series Analysis, Model Evaluation (accuracy, precision, recall, F1, RMSE, AUC), Feature Engineering, Hyperparameter Tuning.
# *   **Databases:** SQL (PostgreSQL, MySQL, SQLite), NoSQL (MongoDB, Cassandra - if applicable).
# *   **Data Visualization:** Matplotlib, Seaborn, Plotly, Tableau, Power BI, Looker.
# *   **Big Data Tools:** Hadoop, Spark (if you have project experience).
# *   **Cloud Platforms:** AWS (S3, EC2, SageMaker), Google Cloud Platform (BigQuery, AI Platform), Azure (Machine Learning Studio - if applicable).
# *   **Development Tools/Version Control:** Git, GitHub, Jupyter Notebooks, VS Code.
# *   **Statistics:** Hypothesis Testing, A/B Testing, Inferential Statistics, Descriptive Statistics, Probability.
# *   **Soft Skills:** Problem-solving, Critical Thinking, Communication, Teamwork, Attention to Detail, Curiosity. (Keep to 2-3 most relevant and demonstrate them in projects).
#
# **Format Tip:** Group skills logically (e.g., Programming, ML Frameworks, Databases, Tools, Cloud, Soft Skills).
#
# ---
#
# ### **4. Projects (The Most Important Section for Freshers)**
#
# This is where you demonstrate your practical abilities. Aim for **3-5 strong, relevant projects**. For each project, use the **STAR method** (Situation, Task, Action, Result) implicitly and quantify impact.
#
# *   **Project Title** | Role (if a team project) | Date
#     *   **Problem:** Clearly state the problem or objective of the project.
#     *   **Methods:** Outline the methodologies, algorithms, and techniques you used (e.g., "Implemented a RandomForest Classifier," "Performed PCA for dimensionality reduction").
#     *   **Tools:** List the specific tools and libraries used (e.g., "Utilized Python, Pandas, Scikit-learn, Matplotlib").
#     *   **Results/Impact:** **Quantify everything!** This is crucial.
#         *   "Achieved an **85% accuracy** in predicting customer churn."
#         *   "Reduced data processing time by **30%** using NumPy optimizations."
#         *   "Built an interactive dashboard in Plotly that **visualized key trends** in X and Y."
#         *   "Identified **top 3 features** impacting X, leading to [potential insight/recommendation]."
#     *   **Link to GitHub Repository:** Make sure it's clean, well-documented, and executable.
#
# **Types of Projects to Include:**
# *   Academic Capstone Projects/Theses
# *   Personal Projects ( Kaggle competitions, self-initiated projects)
# *   Hackathon Projects
# *   Open-source contributions (if significant)
#
# ---
#
# ### **5. Internships / Relevant Experience (If Any)**
#
# If you have any internships (even unpaid or research assistant roles), put them here. Treat them like mini-projects, focusing on your contributions and quantifiable results.
#
# *   **Job Title** | Company Name | Location | Dates
#     *   Use action verbs to describe responsibilities and achievements.
#     *   Focus on data-related tasks: data collection, cleaning, analysis, model building, report generation.
#     *   **Quantify impact** wherever possible.
#
# ---
#
# ### **6. Education**
#
# This is a key section for freshers.
#
# *   **Degree (e.g., Master of Science in Data Science, Bachelor of Technology in Computer Science)**
# *   **University Name** | Location | Graduation Date (Month, Year)
# *   **GPA (Optional):** Include if 3.0/4.0 or higher (or equivalent).
# *   **Relevant Coursework:** List 4-6 most relevant courses (e.g., Machine Learning, Statistical Inference, Database Management, Deep Learning, Data Structures & Algorithms).
# *   **Thesis/Dissertation Title (if applicable):** Briefly describe the focus if relevant to DS.
#
# ---
#
# ### **7. Certifications / Awards / Publications (Optional)**
#
# *   **Certifications:** (e.g., AWS Certified Machine Learning Specialty, Google Data Analytics Professional Certificate, Coursera Specializations). Include title, issuing body, and date.
# *   **Awards:** Academic honors, scholarships, hackathon wins.
# *   **Publications:** If you co-authored any research papers.
#
# ---
#
# ### **General Formatting and Best Practices:**
#
# *   **Length:** **One page, almost always.** Recruiters spend very little time on each resume.
# *   **Clean and Professional Layout:**
#     *   Use a modern, sans-serif font (e.g., Calibri, Lato, Montserrat, Arial).
#     *   Maintain consistent formatting (bullet points, dates, headings).
#     *   Use clear headings for each section.
#     *   Leave ample white space to make it easy to read.
# *   **Action Verbs:** Start bullet points with strong action verbs (e.g., *Analyzed, Developed, Implemented, Modeled, Visualized, Optimized, Designed, Collaborated*).
# *   **Tailor Each Resume:** **Customize your resume for *each* job application.** Read the job description carefully and incorporate keywords and demonstrate skills directly relevant to that specific role.
# *   **Proofread Meticulously:** Typos and grammatical errors instantly detract from professionalism. Ask someone else to review it too.
# *   **Save as PDF:** Always submit your resume as a PDF to preserve formatting.
# *   **Keywords:** Sprinkle keywords from the job description throughout your resume (especially in skills and projects sections) to help with ATS.
#
# ---
#
# **Example Snippet for a Project:**
#
# **Predictive Model for Customer Churn** | Personal Project | May 2023
# *   Developed a machine learning model to predict customer churn for a telecom company using a publicly available dataset.
# *   Performed extensive exploratory data analysis (EDA), feature engineering, and data preprocessing using Pandas and NumPy.
# *   Implemented and fine-tuned various classification algorithms (Logistic Regression, Random Forest, Gradient Boosting) with Scikit-learn.
# *   Achieved an **88% accuracy** and an **AUC score of 0.85** on the test set, outperforming baseline models.
# *   Identified **top 3 features** influencing churn (e.g., contract type, monthly charges, total charges), providing actionable insights.
# *   Visualized key findings and model performance using Matplotlib and Seaborn.
# *   [GitHub Link: github.com/yourusername/churn-prediction]
#
# ---
#
# By following these guidelines, a Data Science fresher can create a compelling resume that effectively showcases their potential and lands them interviews.

# %%
# !pip install streamlit #Install Streamlit in Colab
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.52.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.13.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.12/dist-packages (7.5.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai

# ---------- CONFIGURE GEMINI ----------
genai.configure(api_key="AIzayB4lpvQt08MkOHMqWMqtE2bAOhvTVVrc")
model = genai.GenerativeModel("gemini-2.5-flash")

st.set_page_config(page_title="Smart Chat 🤖")
st.title("AI Chat App 🤖")

# ---------- CHAT MEMORY ----------
if "chat" not in st.session_state:
    st.session_state.chat = []

question = st.text_input("Ask your question 👇")

col1, col2 = st.columns(2)

# ---------- GET ANSWER BUTTON ----------
with col1:
    if st.button("Get Answer"):
        if question.strip() == "":
            st.warning("Please type something first 📝")
        else:
            with st.spinner("Thinking... 🤔"):
                reply = model.generate_content(question).text

            # save conversation
            st.session_state.chat.append(("You", question))
            st.session_state.chat.append(("AI", reply))

# ---------- END CHAT ----------
with col2:
    if st.button("End Here"):
        st.session_state.chat = []
        st.success("Chat Ended 😊")

# ---------- DISPLAY CHAT ----------
st.write("### Chat History")
for sender, msg in st.session_state.chat:
    if sender == "You":
        st.markdown(f"🧑 **You:** {msg}")
    else:
        st.markdown(f"🤖 **AI:** {msg}")
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py & npx --yes localtunnel --port 8501
# Out:
# ⠙⠹
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.147.24.233:8501
#
# your url is: https://thin-memes-press.loca.lt
#   Stopping...
# ^C

# %%
# !pip install cloudflared
# Out:
# Requirement already satisfied: cloudflared in /usr/local/lib/python3.12/dist-packages (1.0.0.2)
# Requirement already satisfied: setuptools-scm in /usr/local/lib/python3.12/dist-packages (from cloudflared) (9.2.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from setuptools-scm->cloudflared) (25.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from setuptools-scm->cloudflared) (75.2.0)

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !mv cloudflared /usr/local/bin/
# Out:
# --2025-12-28 17:21:27--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.11.1/cloudflared-linux-amd64 [following]
# --2025-12-28 17:21:27--  https://github.com/cloudflare/cloudflared/releases/download/2025.11.1/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/955e9d1b-ac5e-4188-8867-e5f53958a8fe?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-28T17%3A54%3A37Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-28T16%3A54%3A14Z&ske=2025-12-28T17%3A54%3A37Z&sks=b&skv=2018-11-09&sig=HZXpHShFLpNCFJKVzhlYlMbD24A0gUZUEzuB2fqcZyo%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Njk0NDI4NywibmJmIjoxNzY2OTQyNDg3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.Dnj6TXYK1pSqNnwIyaps97wOVPsE2_tPOxHSG7RggK0&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream [following]
# --2025-12-28 17:21:27--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/955e9d1b-ac5e-4188-8867-e5f53958a8fe?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-28T17%3A54%3A37Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-28T16%3A54%3A14Z&ske=2025-12-28T17%3A54%3A37Z&sks=b&skv=2018-11-09&sig=HZXpHShFLpNCFJKVzhlYlMbD24A0gUZUEzuB2fqcZyo%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Njk0NDI4NywibmJmIjoxNzY2OTQyNDg3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.Dnj6TXYK1pSqNnwIyaps97wOVPsE2_tPOxHSG7RggK0&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41258324 (39M) [application/octet-stream]
# Saving to: ‘cloudflared’
#
# cloudflared         100%[===================>]  39.35M  62.1MB/s    in 0.6s
#
# 2025-12-28 17:21:28 (62.1 MB/s) - ‘cloudflared’ saved [41258324/41258324]

# %%
import threading
import subprocess
import time

# start streamlit
def run_streamlit():
    subprocess.call(["streamlit", "run", "app.py"])

thread = threading.Thread(target=run_streamlit)
thread.start()

time.sleep(5)

# !cloudflared tunnel --url http://localhost:8501 --no-autoupdate
# Out:
# 2025-12-28T17:21:41Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2025-12-28T17:21:41Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2025-12-28T17:21:47Z INF +--------------------------------------------------------------------------------------------+
# 2025-12-28T17:21:47Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2025-12-28T17:21:47Z INF |  https://nashville-bathroom-bucks-hose.trycloudflare.com                                   |
# 2025-12-28T17:21:47Z INF +--------------------------------------------------------------------------------------------+
# 2025-12-28T17:21:47Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2025-12-28T17:21:47Z INF Version 2025.11.1 (Checksum 991dffd8889ee9f0147b6b48933da9e4407e68ea8c6d984f55fa2d3db4bb431d)
# 2025-12-28T17:21:47Z INF GOOS: linux, GOVersion: go1.24.9, GoArch: amd64
# 2025-12-28T17:21:47Z INF Settings: map[ha-connections:1 no-autoupdate:true protocol:quic url:http://localhost:8501]
# 2025-12-28T17:21:47Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2025-12-28T17:21:47Z INF Generated Connector ID: d64e48bc-32bf-40d4-9198-406dc51cdd76
# 2025-12-28T17:21:47Z INF Initial protocol quic
# 2025-12-28T17:21:47Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2025-12-28T17:21:47Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2025-12-28T17:21:47Z ERR Cannot determine default origin certificate path. No file cert.pem in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]. You need to specify the origin certificate path by specifying the origincert option in the configuration file, or set TUNNEL_ORIGIN_CERT environment variable originCertPath=
# 2025-12-28T17:21:47Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2025-12-28T17:21:47Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2025-12-28T17:21:47Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2025-12-28T17:21:47Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.27
# 2025/12/28 17:21:47 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2025-12-28T17:21:47Z INF Registered tunnel connection connIndex=0 connection=6d4f88cd-76b6-47bf-bb81-a6612ac7f855 event=0 ip=198.41.192.27 location=ams15 protocol=quic
# 2025-12-28T17:39:46Z INF Initiating graceful shutdown due to signal interrupt ...
# 2025-12-28T17:39:46Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.27
# 2025-12-28T17:39:46Z ERR failed to serve tunnel connection error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2025-12-28T17:39:46Z ERR Serve tunnel error error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2025-12-28T17:39:46Z INF Retrying connection in up to 1s connIndex=0 event=0 ip=198.41.192.27
# 2025-12-28T17:39:46Z ERR Connection terminated connIndex=0
# 2025-12-28T17:39:46Z ERR no more connections active and exiting
# 2025-12-28T17:39:46Z INF Tunnel server stopped
# 2025-12-28T17:39:46Z INF Metrics server stopped
